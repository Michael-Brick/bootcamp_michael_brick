# %% [markdown]
# Environment & Config Check

# %%
import sys, os
print("Python version:", sys.version)
print("Interpreter path:", sys.executable)
try:
    import numpy as np
    from dotenv import load_dotenv
    from pathlib import Path
    print("Imports OK")
except Exception as e:
    print("Import error:", e)
    raise

def get_key(name, default=None):
    return os.getenv(name, default)

PROJECT_ROOT = Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"
print("PROJECT_ROOT:", PROJECT_ROOT)
print("DATA_DIR:", DATA_DIR)
load_dotenv()
api_key_present = get_key("API_KEY") is not None
print("API_KEY present:", api_key_present)
arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)
print("Mean:", arr.mean())
print("Vectorized * 10:", arr * 10)
# Out:
# Python version: 3.11.15 | packaged by Anaconda, Inc. | (main, Jun 11 2026, 15:12:53) [MSC v.1942 64 bit (AMD64)]
# Interpreter path: c:\Users\schwa\miniconda3\envs\fe-course\python.exe
# Imports OK
# PROJECT_ROOT: c:\Users\schwa\bootcamp_michael_brick\homework\homework02
# DATA_DIR: c:\Users\schwa\bootcamp_michael_brick\homework\homework02\data
# API_KEY present: True
# Array: [1 2 3 4 5]
# Mean: 3.0
# Vectorized * 10: [10 20 30 40 50]
